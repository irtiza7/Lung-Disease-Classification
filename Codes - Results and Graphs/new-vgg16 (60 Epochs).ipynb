# %%
import numpy as np
import pandas as pd
from glob import glob
from tqdm import tqdm
from sklearn.utils import shuffle
import os

# %%
df = pd.read_csv('../input/data/Data_Entry_2017.csv')

diseases = ['Cardiomegaly','Emphysema','Effusion','Hernia','Nodule','Pneumothorax','Atelectasis','Pleural_Thickening','Mass','Edema','Consolidation','Infiltration','Fibrosis','Pneumonia']
#Number diseases
for disease in diseases :
    df[disease] = df['Finding Labels'].apply(lambda x: 1 if disease in x else 0)

# %%
all_image_paths = {os.path.basename(x): x for x in glob(os.path.join('..', 'input','data','images*','images','*.png'))}

print('Images found:', len(all_image_paths))
df['Path'] = df['Image Index'].map(all_image_paths.get)
# Out:
# Images found: 112120

# %%
labels = df[diseases].to_numpy()
files_list = df['Path'].tolist()

# %%
labelB = (df[diseases].sum(axis=1)>0).tolist()
labelB = np.array(labelB, dtype=int)
print(labelB)
# Out:
# [1 1 1 ... 0 0 0]

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(df, test_size = 0.33, random_state = 2018,)
print(f'Training : {train_df.shape[0]} samples  \nTesting: {test_df.shape[0]} samples')
# Out:
# Training : 75120 samples
# Testing: 37000 samples

# %%
patient_train = set(train_df["Patient ID"].values)
patient_test  = set(test_df["Patient ID"].values)

leakage_patient = patient_train.intersection(patient_test)
print(len(leakage_patient))
# Out:
# 9733

# %%
train_without_leakage = train_df[~train_df["Patient ID"].isin(leakage_patient)]

print("Train")
print(len(train_without_leakage) / len(train_df))
print(len(train_df))
print(len(train_without_leakage))

print()
print("Test")
test_without_leakage = test_df[~test_df["Patient ID"].isin(leakage_patient)]
print(len(test_without_leakage) / len(test_df))
print(len(test_df))
print(len(test_without_leakage))
# Out:
# Train
# 0.2656283280085197
# 75120
# 19954
#
# Test
# 0.18975675675675677
# 37000
# 7021

# %%
test_df = test_without_leakage

# %%
train_df, valid_df = train_test_split(train_df, test_size = 0.2, random_state = 42)

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path, shape):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=shape)
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)/255
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths, shape):
    list_of_tensors = [path_to_tensor(img_path, shape) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
img_shape = (64, 64)
train_tensors = paths_to_tensor(train_df['Path'].to_list(), shape = img_shape)
valid_tensors = paths_to_tensor(valid_df['Path'].to_list(), shape = img_shape)
test_tensors = paths_to_tensor(test_df['Path'].to_list(), shape = img_shape)
# Out:
# 100%|██████████| 60096/60096 [23:20<00:00, 42.91it/s]
# 100%|██████████| 15024/15024 [05:48<00:00, 43.12it/s]
# 100%|██████████| 7021/7021 [02:51<00:00, 40.89it/s]

# %%
train_labels = (train_df[diseases].sum(axis=1)>0).tolist()
train_labels = np.array(train_labels, dtype=int)
train_labels =train_labels[:, np.newaxis]

# %%
train_labels
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [1],
#        [1],
#        [0]])

# %%
valid_labels = (valid_df[diseases].sum(axis=1)>0).tolist()
valid_labels = np.array(valid_labels, dtype=int)
valid_labels =valid_labels[:, np.newaxis]

# %%
test_labels = (test_df[diseases].sum(axis=1)>0).tolist()
test_labels = np.array(test_labels, dtype=int)
test_labels =test_labels[:, np.newaxis]

# %%
import time

from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, Flatten, Dense
from keras.models import Sequential, Model
from keras.layers import BatchNormalization
from keras import regularizers, applications, optimizers, initializers
from keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.keras.applications.vgg16 import VGG16

base_model = VGG16(weights='imagenet', include_top=False, input_shape=train_tensors.shape[1:])

add_model = Sequential()
add_model.add(Flatten(input_shape=base_model.output_shape[1:]))
add_model.add(Dropout(0.2))
add_model.add(Dense(256, activation='relu'))
add_model.add(Dropout(0.2))

add_model.add(Dense(512, activation='relu'))
add_model.add(Dropout(0.2))
add_model.add(Dense(256, activation='relu'))
add_model.add(Dropout(0.2))

add_model.add(Dense(50, activation='relu'))
add_model.add(Dropout(0.2))
add_model.add(Dense(1, activation='sigmoid'))

model = Model(inputs=base_model.input, outputs=add_model(base_model.output))

# model.summary()
# add_model.summary()
# Out:
# 2022-11-29 11:54:15.703567: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 11:54:15.891909: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 11:54:15.892771: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 11:54:15.894155: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-29 11:54:15.894568: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 11:54:15.895277: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 11:54:15.895925: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 11:54:18.086897: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 11:54:18.087791: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 11:54:18.088459: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 11:54:18.089941: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step

# %%
from keras import backend as K

def binary_accuracy(y_true, y_pred):
    return K.mean(K.equal(y_true, K.round(y_pred)))

def precision_threshold(threshold = 0.5):
    def precision(y_true, y_pred):
        threshold_value = threshold
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold_value), K.floatx())
        true_positives = K.round(K.sum(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(y_pred)
        precision_ratio = true_positives / (predicted_positives + K.epsilon())
        return precision_ratio
    return precision

# %%
def recall_threshold(threshold = 0.5):
    def recall(y_true, y_pred):
        threshold_value = threshold
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold_value), K.floatx())
        true_positives = K.round(K.sum(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.clip(y_true, 0, 1))
        recall_ratio = true_positives / (possible_positives + K.epsilon())
        return recall_ratio
    return recall

# %%
def fbeta_score_threshold(beta = 1, threshold = 0.5):
    def fbeta_score(y_true, y_pred):
        threshold_value = threshold
        beta_value = beta
        p = precision_threshold(threshold_value)(y_true, y_pred)
        r = recall_threshold(threshold_value)(y_true, y_pred)
        bb = beta_value ** 2
        fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
        return fbeta_score
    return fbeta_score

# %%
import keras.backend as K
from tensorflow.keras import optimizers

model.compile(
    optimizer=optimizers.SGD(learning_rate=1e-4, decay=1e-6, momentum=0.9, nesterov=True), 
    loss='binary_crossentropy', 
    metrics=[
        'accuracy',
        precision_threshold(threshold = 0.5), 
        recall_threshold(threshold = 0.5), 
        fbeta_score_threshold(beta=0.5, threshold = 0.5)
    ]
)

# %%
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping
import numpy as np

Epochs = 60
batch_size = 32

earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=4, verbose=1, mode='auto')
log = CSVLogger('saved_models/log_pretrained_CNN.csv')
checkpointer = ModelCheckpoint(filepath='saved_models/pretrainedVGG.best.from_scratch.hdf5', verbose=1, save_best_only=True)

# %%
train_datagen = ImageDataGenerator(
                        featurewise_center=False,  # set input mean to 0 over the dataset
                        samplewise_center=False,  # set each sample mean to 0
                        featurewise_std_normalization=False,  # divide inputs by std of the dataset
                        samplewise_std_normalization=False,  # divide each input by its std
                        zca_whitening=False,  # apply ZCA whitening
                        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
                        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
                        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
                        horizontal_flip=True,  # randomly flip images
                        vertical_flip=False 
)

# %%
# %%timeit -n1 -r1

# Training with data augmentation. If shift_fraction=0., also no augmentation.
history = model.fit_generator(
    train_datagen.flow(train_tensors,train_labels, batch_size = batch_size),
    steps_per_epoch = len(train_tensors) // batch_size,
    validation_data = (valid_tensors, valid_labels),
    validation_steps = len(valid_tensors) // batch_size,
    epochs = Epochs,    
)
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2022-11-29 11:54:19.118560: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/60
# 2022-11-29 11:54:21.483114: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 1877/1878 [============================>.] - ETA: 0s - loss: 0.6740 - accuracy: 0.5803 - precision: 0.5504 - recall: 0.4344 - fbeta_score: 0.5094
# 2022-11-29 11:55:53.894301: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 738459648 exceeds 10% of free system memory.
# 1878/1878 [==============================] - 106s 52ms/step - loss: 0.6740 - accuracy: 0.5804 - precision: 0.5505 - recall: 0.4346 - fbeta_score: 0.5095 - val_loss: 0.6288 - val_accuracy: 0.6603 - val_precision: 0.6738 - val_recall: 0.5165 - val_fbeta_score: 0.6281
# Epoch 2/60
# 1878/1878 [==============================] - 86s 46ms/step - loss: 0.6351 - accuracy: 0.6537 - precision: 0.6415 - recall: 0.5726 - fbeta_score: 0.6156
# Epoch 3/60
# 1878/1878 [==============================] - 86s 46ms/step - loss: 0.6242 - accuracy: 0.6664 - precision: 0.6526 - recall: 0.5910 - fbeta_score: 0.6297
# Epoch 4/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.6193 - accuracy: 0.6731 - precision: 0.6631 - recall: 0.5972 - fbeta_score: 0.6385
# Epoch 5/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.6153 - accuracy: 0.6778 - precision: 0.6665 - recall: 0.6031 - fbeta_score: 0.6436
# Epoch 6/60
# 1878/1878 [==============================] - 86s 46ms/step - loss: 0.6118 - accuracy: 0.6796 - precision: 0.6675 - recall: 0.6042 - fbeta_score: 0.6453
# Epoch 7/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.6095 - accuracy: 0.6832 - precision: 0.6716 - recall: 0.6093 - fbeta_score: 0.6497
# Epoch 8/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.6086 - accuracy: 0.6839 - precision: 0.6720 - recall: 0.6079 - fbeta_score: 0.6498
# Epoch 9/60
# 1878/1878 [==============================] - 86s 46ms/step - loss: 0.6073 - accuracy: 0.6854 - precision: 0.6738 - recall: 0.6181 - fbeta_score: 0.6537
# Epoch 10/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.6057 - accuracy: 0.6884 - precision: 0.6759 - recall: 0.6155 - fbeta_score: 0.6552
# Epoch 11/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.6039 - accuracy: 0.6874 - precision: 0.6760 - recall: 0.6143 - fbeta_score: 0.6548
# Epoch 12/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.6041 - accuracy: 0.6880 - precision: 0.6757 - recall: 0.6185 - fbeta_score: 0.6557
# Epoch 13/60
# 1878/1878 [==============================] - 84s 45ms/step - loss: 0.6020 - accuracy: 0.6914 - precision: 0.6797 - recall: 0.6236 - fbeta_score: 0.6597
# Epoch 14/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.6007 - accuracy: 0.6890 - precision: 0.6769 - recall: 0.6206 - fbeta_score: 0.6573
# Epoch 15/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.6000 - accuracy: 0.6910 - precision: 0.6798 - recall: 0.6215 - fbeta_score: 0.6590
# Epoch 16/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.5994 - accuracy: 0.6925 - precision: 0.6805 - recall: 0.6265 - fbeta_score: 0.6613
# Epoch 17/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.5992 - accuracy: 0.6923 - precision: 0.6802 - recall: 0.6261 - fbeta_score: 0.6612
# Epoch 18/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.5968 - accuracy: 0.6938 - precision: 0.6801 - recall: 0.6318 - fbeta_score: 0.6631
# Epoch 19/60
# 1878/1878 [==============================] - 84s 45ms/step - loss: 0.5978 - accuracy: 0.6926 - precision: 0.6787 - recall: 0.6311 - fbeta_score: 0.6611
# Epoch 20/60
# 1878/1878 [==============================] - 84s 45ms/step - loss: 0.5961 - accuracy: 0.6958 - precision: 0.6826 - recall: 0.6332 - fbeta_score: 0.6648
# Epoch 21/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.5956 - accuracy: 0.6950 - precision: 0.6810 - recall: 0.6326 - fbeta_score: 0.6638
# Epoch 22/60
# 1878/1878 [==============================] - 84s 45ms/step - loss: 0.5956 - accuracy: 0.6945 - precision: 0.6806 - recall: 0.6321 - fbeta_score: 0.6631
# Epoch 23/60
# 1878/1878 [==============================] - 83s 44ms/step - loss: 0.5940 - accuracy: 0.6967 - precision: 0.6847 - recall: 0.6304 - fbeta_score: 0.6659
# Epoch 24/60
# 1878/1878 [==============================] - 84s 45ms/step - loss: 0.5938 - accuracy: 0.6966 - precision: 0.6825 - recall: 0.6324 - fbeta_score: 0.6651
# Epoch 25/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.5931 - accuracy: 0.6987 - precision: 0.6879 - recall: 0.6337 - fbeta_score: 0.6692
# Epoch 26/60
# 1878/1878 [==============================] - 84s 45ms/step - loss: 0.5924 - accuracy: 0.6974 - precision: 0.6857 - recall: 0.6322 - fbeta_score: 0.6670
# Epoch 27/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.5924 - accuracy: 0.6987 - precision: 0.6880 - recall: 0.6361 - fbeta_score: 0.6694
# Epoch 28/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.5913 - accuracy: 0.6991 - precision: 0.6855 - recall: 0.6353 - fbeta_score: 0.6678
# Epoch 29/60
# 1878/1878 [==============================] - 84s 45ms/step - loss: 0.5909 - accuracy: 0.6985 - precision: 0.6864 - recall: 0.6345 - fbeta_score: 0.6683
# Epoch 30/60
# 1878/1878 [==============================] - 84s 45ms/step - loss: 0.5904 - accuracy: 0.6993 - precision: 0.6859 - recall: 0.6375 - fbeta_score: 0.6686
# Epoch 31/60
# 1878/1878 [==============================] - 85s 45ms/step - loss: 0.5897 - accuracy: 0.6998 - precision: 0.6878 - recall: 0.6360 - fbeta_score: 0.6700
# Epoch 32/60
# 1878/1878 [==============================] - 84s 45ms/step - loss: 0.5890 - accuracy: 0.7017 - precision: 0.6895 - recall: 0.6415 - fbeta_score: 0.6721
# Epoch 33/60
# 1878/1878 [==============================] - 84s 45ms/step - loss: 0.5885 - accuracy: 0.7004 - precision: 0.6870 - recall: 0.6376 - fbeta_score: 0.6695
# Epoch 34/60
# 1878/1878 [==============================] - 84s 45ms/step - loss: 0.5880 - accuracy: 0.7019 - precision: 0.6881 - recall: 0.6385 - fbeta_score: 0.6707
# Epoch 35/60
# 1878/1878 [==============================] - 83s 44ms/step - loss: 0.5871 - accuracy: 0.7026 - precision: 0.6893 - recall: 0.6432 - fbeta_score: 0.6728
# Epoch 36/60
# 1878/1878 [==============================] - 83s 44ms/step - loss: 0.5874 - accuracy: 0.7013 - precision: 0.6878 - recall: 0.6389 - fbeta_score: 0.6706
# Epoch 37/60
# 1878/1878 [==============================] - 84s 45ms/step - loss: 0.5866 - accuracy: 0.7032 - precision: 0.6900 - recall: 0.6428 - fbeta_score: 0.6735
# Epoch 38/60
# 1878/1878 [==============================] - 84s 45ms/step - loss: 0.5854 - accuracy: 0.7042 - precision: 0.6910 - recall: 0.6426 - fbeta_score: 0.6737
# Epoch 39/60
# 1878/1878 [==============================] - 84s 45ms/step - loss: 0.5846 - accuracy: 0.7049 - precision: 0.6926 - recall: 0.6412 - fbeta_score: 0.6748
# Epoch 40/60
# 1878/1878 [==============================] - 83s 44ms/step - loss: 0.5859 - accuracy: 0.7043 - precision: 0.6938 - recall: 0.6406 - fbeta_score: 0.6756
# Epoch 41/60
# 1878/1878 [==============================] - 83s 44ms/step - loss: 0.5843 - accuracy: 0.7042 - precision: 0.6918 - recall: 0.6440 - fbeta_score: 0.6749
# Epoch 42/60
# 1878/1878 [==============================] - 83s 44ms/step - loss: 0.5835 - accuracy: 0.7052 - precision: 0.6907 - recall: 0.6494 - fbeta_score: 0.6754
# Epoch 43/60
# 1878/1878 [==============================] - 82s 44ms/step - loss: 0.5833 - accuracy: 0.7056 - precision: 0.6926 - recall: 0.6410 - fbeta_score: 0.6745
# Epoch 44/60
# 1878/1878 [==============================] - 84s 44ms/step - loss: 0.5831 - accuracy: 0.7059 - precision: 0.6909 - recall: 0.6487 - fbeta_score: 0.6757
# Epoch 45/60
# 1878/1878 [==============================] - 82s 44ms/step - loss: 0.5820 - accuracy: 0.7074 - precision: 0.6948 - recall: 0.6495 - fbeta_score: 0.6784
# Epoch 46/60
# 1878/1878 [==============================] - 81s 43ms/step - loss: 0.5824 - accuracy: 0.7071 - precision: 0.6937 - recall: 0.6471 - fbeta_score: 0.6772
# Epoch 47/60
# 1878/1878 [==============================] - 83s 44ms/step - loss: 0.5813 - accuracy: 0.7081 - precision: 0.6948 - recall: 0.6504 - fbeta_score: 0.6785
# Epoch 48/60
# 1878/1878 [==============================] - 82s 44ms/step - loss: 0.5814 - accuracy: 0.7080 - precision: 0.6949 - recall: 0.6520 - fbeta_score: 0.6792
# Epoch 49/60
# 1878/1878 [==============================] - 82s 44ms/step - loss: 0.5809 - accuracy: 0.7082 - precision: 0.6955 - recall: 0.6496 - fbeta_score: 0.6791
# Epoch 50/60
# 1878/1878 [==============================] - 82s 44ms/step - loss: 0.5799 - accuracy: 0.7104 - precision: 0.6968 - recall: 0.6534 - fbeta_score: 0.6809
# Epoch 51/60
# 1878/1878 [==============================] - 82s 44ms/step - loss: 0.5787 - accuracy: 0.7099 - precision: 0.6953 - recall: 0.6521 - fbeta_score: 0.6799
# Epoch 52/60
# 1878/1878 [==============================] - 82s 44ms/step - loss: 0.5783 - accuracy: 0.7104 - precision: 0.6967 - recall: 0.6524 - fbeta_score: 0.6810
# Epoch 53/60
# 1878/1878 [==============================] - 82s 44ms/step - loss: 0.5780 - accuracy: 0.7094 - precision: 0.6959 - recall: 0.6518 - fbeta_score: 0.6803
# Epoch 54/60
# 1878/1878 [==============================] - 82s 44ms/step - loss: 0.5776 - accuracy: 0.7112 - precision: 0.6994 - recall: 0.6500 - fbeta_score: 0.6824
# Epoch 55/60
# 1878/1878 [==============================] - 83s 44ms/step - loss: 0.5766 - accuracy: 0.7124 - precision: 0.6988 - recall: 0.6546 - fbeta_score: 0.6835
# Epoch 56/60
# 1878/1878 [==============================] - 82s 44ms/step - loss: 0.5768 - accuracy: 0.7129 - precision: 0.6999 - recall: 0.6569 - fbeta_score: 0.6843
# Epoch 57/60
# 1878/1878 [==============================] - 83s 44ms/step - loss: 0.5756 - accuracy: 0.7116 - precision: 0.6972 - recall: 0.6553 - fbeta_score: 0.6819
# Epoch 58/60
# 1878/1878 [==============================] - 82s 43ms/step - loss: 0.5763 - accuracy: 0.7114 - precision: 0.6968 - recall: 0.6570 - fbeta_score: 0.6817
# Epoch 59/60
# 1878/1878 [==============================] - 83s 44ms/step - loss: 0.5749 - accuracy: 0.7130 - precision: 0.7003 - recall: 0.6593 - fbeta_score: 0.6850
# Epoch 60/60
# 1878/1878 [==============================] - 82s 44ms/step - loss: 0.5733 - accuracy: 0.7131 - precision: 0.6980 - recall: 0.6569 - fbeta_score: 0.6831
# 1h 24min 14s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
prediction = model.predict(test_tensors)
# Out:
# 2022-11-29 13:18:33.409628: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 345096192 exceeds 10% of free system memory.
# 2022-11-29 13:18:33.581093: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 345096192 exceeds 10% of free system memory.

# %%
threshold = 0.5
beta = 0.5

pre = K.eval(precision_threshold(threshold = threshold)(K.variable(value=test_labels), K.variable(value=prediction)))
rec = K.eval(recall_threshold(threshold = threshold)(K.variable(value=test_labels), K.variable(value=prediction)))
fsc = K.eval(fbeta_score_threshold(beta = beta, threshold = threshold)(K.variable(value=test_labels), K.variable(value=prediction)))

print ("Precision: %f %%\nRecall: %f %%\nFscore: %f %%"% (pre, rec, fsc))
# Out:
# Precision: 0.654378 %
# Recall: 0.272161 %
# Fscore: 0.510883 %

# %%
K.eval(binary_accuracy(K.variable(value=test_labels), K.variable(value=prediction)))
# Out:
# 0.7409201

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# %%
roc_auc_score(test_labels, prediction)
# Out:
# 0.7229928588756347

# %%
model.save('vgg16-model.h5')

# %%
model.save_weights('vgg16-w-model.h5')
