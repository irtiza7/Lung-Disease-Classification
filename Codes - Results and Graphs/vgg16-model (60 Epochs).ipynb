# %%
# This Python 3 environment comes with many helpful analytics libraries installed
import numpy as np
import pandas as pd
from glob import glob
from tqdm import tqdm
from sklearn.utils import shuffle

df = pd.read_csv('../input/data/Data_Entry_2017.csv')

diseases = ['Cardiomegaly','Emphysema','Effusion','Hernia','Nodule','Pneumothorax','Atelectasis','Pleural_Thickening','Mass','Edema','Consolidation','Infiltration','Fibrosis','Pneumonia']
#Number diseases
for disease in diseases :
    df[disease] = df['Finding Labels'].apply(lambda x: 1 if disease in x else 0)

# %%
import os
labels = df[diseases].to_numpy()
all_image_paths = {os.path.basename(x): x for x in 
                   glob(os.path.join('..', 'input','data','images*','images','*.png'))}
print('Images found:', len(all_image_paths))


df['Path'] = df['Image Index'].map(all_image_paths.get)
files_list = df['Path'].tolist()

# #test to perfect
# labelB = df['Emphysema'].tolist()

labelB = (df[diseases].sum(axis=1)>0).tolist()
labelB = np.array(labelB, dtype=int)
# Out:
# Images found: 112120

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path, shape):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=shape)
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)/255
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths, shape):
    list_of_tensors = [path_to_tensor(img_path, shape) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

train_labels = labelB[:89600][:, np.newaxis]
valid_labels = labelB[89600:100800][:, np.newaxis]
test_labels = labelB[100800:][:, np.newaxis]

img_shape = (64, 64)
train_tensors = paths_to_tensor(files_list[:89600], shape = img_shape)
valid_tensors = paths_to_tensor(files_list[89600:100800], shape = img_shape)
test_tensors = paths_to_tensor(files_list[100800:], shape = img_shape)
# Out:
# 100%|██████████| 89600/89600 [38:09<00:00, 39.14it/s]
# 100%|██████████| 11200/11200 [04:46<00:00, 39.14it/s]
# 100%|██████████| 11320/11320 [04:47<00:00, 39.32it/s]

# %%
import time

from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, Flatten, Dense
from keras.models import Sequential, Model
from keras.layers import BatchNormalization
from keras import regularizers, applications, optimizers, initializers
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16

# VGG16
# resnet50.ResNet50
# inception_v3.InceptionV3 299x299
# inception_resnet_v2.InceptionResNetV2 299x299

base_model = VGG16(weights='imagenet', 
                                include_top=False, 
                                input_shape=train_tensors.shape[1:])

add_model = Sequential()
add_model.add(Flatten(input_shape=base_model.output_shape[1:]))
add_model.add(Dropout(0.2))
add_model.add(Dense(256, activation='relu'))
add_model.add(Dropout(0.2))
add_model.add(Dense(50, activation='relu'))
add_model.add(Dropout(0.2))
add_model.add(Dense(1, activation='sigmoid'))

model = Model(inputs=base_model.input, outputs=add_model(base_model.output))

model.summary()
# Out:
# 2022-11-29 18:31:12.680925: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 18:31:12.783872: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 18:31:12.784655: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 18:31:12.786285: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-29 18:31:12.786689: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 18:31:12.787403: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 18:31:12.788078: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 18:31:14.990215: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 18:31:14.991110: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 18:31:14.991865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-29 18:31:14.993265: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# sequential (Sequential)      (None, 1)                 537445
# =================================================================
# Total params: 15,252,133
# Trainable params: 15,252,133
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import backend as K

def binary_accuracy(y_true, y_pred):
    return K.mean(K.equal(y_true, K.round(y_pred)))

def precision_threshold(threshold = 0.5):
    def precision(y_true, y_pred):
        threshold_value = threshold
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold_value), K.floatx())
        true_positives = K.round(K.sum(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(y_pred)
        precision_ratio = true_positives / (predicted_positives + K.epsilon())
        return precision_ratio
    return precision

def recall_threshold(threshold = 0.5):
    def recall(y_true, y_pred):
        threshold_value = threshold
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold_value), K.floatx())
        true_positives = K.round(K.sum(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.clip(y_true, 0, 1))
        recall_ratio = true_positives / (possible_positives + K.epsilon())
        return recall_ratio
    return recall

def fbeta_score_threshold(beta = 1, threshold = 0.5):
    def fbeta_score(y_true, y_pred):
        threshold_value = threshold
        beta_value = beta
        p = precision_threshold(threshold_value)(y_true, y_pred)
        r = recall_threshold(threshold_value)(y_true, y_pred)
        bb = beta_value ** 2
        fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
        return fbeta_score
    return fbeta_score

# %%
import keras.backend as K
import tensorflow as tf

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4, decay=1e-6), 
              loss='binary_crossentropy', 
              metrics=['accuracy',
                      precision_threshold(threshold = 0.5), 
                       recall_threshold(threshold = 0.5), 
                       fbeta_score_threshold(beta=0.5, threshold = 0.5)])

# %%
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping
import numpy as np

epochs = 60
batch_size = 32

earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=4, verbose=1, mode='auto')
log = CSVLogger('saved_models/log_pretrained_CNN.csv')
checkpointer = ModelCheckpoint(filepath='saved_models/pretrainedVGG.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

start = time.time()
train_datagen = ImageDataGenerator(
                        featurewise_center=False,  # set input mean to 0 over the dataset
                        samplewise_center=False,  # set each sample mean to 0
                        featurewise_std_normalization=False,  # divide inputs by std of the dataset
                        samplewise_std_normalization=False,  # divide each input by its std
                        zca_whitening=False,  # apply ZCA whitening
                        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
                        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
                        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
                        horizontal_flip=True,  # randomly flip images
                        vertical_flip=False 
)
history = model.fit_generator(
    train_datagen.flow(train_tensors,train_labels, batch_size = batch_size),
    steps_per_epoch = len(train_tensors) // batch_size,
    validation_data = (valid_tensors, valid_labels),
    validation_steps = len(valid_tensors) // batch_size,
    epochs = epochs,
    callbacks=[checkpointer, log], verbose=1
)
print("training time: %.2f minutes"%((time.time()-start)/60))
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2022-11-29 18:31:15.888977: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/60
# 2022-11-29 18:31:18.521187: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 2800/2800 [==============================] - ETA: 0s - loss: 0.6335 - accuracy: 0.6514 - precision: 0.6416 - recall: 0.5718 - fbeta_score: 0.6097
# 2022-11-29 18:33:29.875930: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 550502400 exceeds 10% of free system memory.
# 2800/2800 [==============================] - 137s 46ms/step - loss: 0.6335 - accuracy: 0.6514 - precision: 0.6416 - recall: 0.5718 - fbeta_score: 0.6097 - val_loss: 0.5910 - val_accuracy: 0.6989 - val_precision: 0.5589 - val_recall: 0.5815 - val_fbeta_score: 0.5513
#
# Epoch 00001: val_loss improved from inf to 0.59102, saving model to saved_models/pretrainedVGG.best.from_scratch.hdf5
# Epoch 2/60
# 2800/2800 [==============================] - 126s 45ms/step - loss: 0.6079 - accuracy: 0.6844 - precision: 0.6721 - recall: 0.6251 - fbeta_score: 0.6532 - val_loss: 0.5825 - val_accuracy: 0.7096 - val_precision: 0.5787 - val_recall: 0.5091 - val_fbeta_score: 0.5435
#
# Epoch 00002: val_loss improved from 0.59102 to 0.58250, saving model to saved_models/pretrainedVGG.best.from_scratch.hdf5
# Epoch 3/60
# 2800/2800 [==============================] - 129s 46ms/step - loss: 0.5997 - accuracy: 0.6916 - precision: 0.6788 - recall: 0.6336 - fbeta_score: 0.6612 - val_loss: 0.5827 - val_accuracy: 0.7118 - val_precision: 0.5737 - val_recall: 0.5539 - val_fbeta_score: 0.5542
#
# Epoch 00003: val_loss did not improve from 0.58250
# Epoch 4/60
# 2800/2800 [==============================] - 134s 48ms/step - loss: 0.5948 - accuracy: 0.6964 - precision: 0.6845 - recall: 0.6373 - fbeta_score: 0.6673 - val_loss: 0.5820 - val_accuracy: 0.7129 - val_precision: 0.5782 - val_recall: 0.5240 - val_fbeta_score: 0.5476
#
# Epoch 00004: val_loss improved from 0.58250 to 0.58201, saving model to saved_models/pretrainedVGG.best.from_scratch.hdf5
# Epoch 5/60
# 2800/2800 [==============================] - 131s 47ms/step - loss: 0.5915 - accuracy: 0.6985 - precision: 0.6859 - recall: 0.6398 - fbeta_score: 0.6688 - val_loss: 0.5749 - val_accuracy: 0.7162 - val_precision: 0.5746 - val_recall: 0.5397 - val_fbeta_score: 0.5527
#
# Epoch 00005: val_loss improved from 0.58201 to 0.57491, saving model to saved_models/pretrainedVGG.best.from_scratch.hdf5
# Epoch 6/60
# 2800/2800 [==============================] - 134s 48ms/step - loss: 0.5869 - accuracy: 0.7025 - precision: 0.6908 - recall: 0.6429 - fbeta_score: 0.6738 - val_loss: 0.5872 - val_accuracy: 0.7138 - val_precision: 0.5804 - val_recall: 0.5409 - val_fbeta_score: 0.5559
#
# Epoch 00006: val_loss did not improve from 0.57491
# Epoch 7/60
# 2800/2800 [==============================] - 131s 47ms/step - loss: 0.5835 - accuracy: 0.7067 - precision: 0.6971 - recall: 0.6466 - fbeta_score: 0.6793 - val_loss: 0.5732 - val_accuracy: 0.7129 - val_precision: 0.5887 - val_recall: 0.4768 - val_fbeta_score: 0.5389
#
# Epoch 00007: val_loss improved from 0.57491 to 0.57321, saving model to saved_models/pretrainedVGG.best.from_scratch.hdf5
# Epoch 8/60
# 2800/2800 [==============================] - 133s 48ms/step - loss: 0.5813 - accuracy: 0.7084 - precision: 0.6982 - recall: 0.6520 - fbeta_score: 0.6814 - val_loss: 0.5791 - val_accuracy: 0.7134 - val_precision: 0.5860 - val_recall: 0.5253 - val_fbeta_score: 0.5547
#
# Epoch 00008: val_loss did not improve from 0.57321
# Epoch 9/60
# 2800/2800 [==============================] - 133s 48ms/step - loss: 0.5790 - accuracy: 0.7094 - precision: 0.6971 - recall: 0.6549 - fbeta_score: 0.6818 - val_loss: 0.5782 - val_accuracy: 0.7106 - val_precision: 0.5888 - val_recall: 0.4740 - val_fbeta_score: 0.5369
#
# Epoch 00009: val_loss did not improve from 0.57321
# Epoch 10/60
# 2800/2800 [==============================] - 132s 47ms/step - loss: 0.5763 - accuracy: 0.7128 - precision: 0.7001 - recall: 0.6617 - fbeta_score: 0.6854 - val_loss: 0.5760 - val_accuracy: 0.7171 - val_precision: 0.5744 - val_recall: 0.5141 - val_fbeta_score: 0.5444
#
# Epoch 00010: val_loss did not improve from 0.57321
# Epoch 11/60
# 2800/2800 [==============================] - 131s 47ms/step - loss: 0.5745 - accuracy: 0.7138 - precision: 0.7010 - recall: 0.6606 - fbeta_score: 0.6858 - val_loss: 0.5786 - val_accuracy: 0.7095 - val_precision: 0.5949 - val_recall: 0.4603 - val_fbeta_score: 0.5337
#
# Epoch 00011: val_loss did not improve from 0.57321
# Epoch 12/60
# 2800/2800 [==============================] - 133s 47ms/step - loss: 0.5708 - accuracy: 0.7167 - precision: 0.7056 - recall: 0.6641 - fbeta_score: 0.6903 - val_loss: 0.5737 - val_accuracy: 0.7169 - val_precision: 0.5802 - val_recall: 0.5435 - val_fbeta_score: 0.5559
#
# Epoch 00012: val_loss did not improve from 0.57321
# Epoch 13/60
# 2800/2800 [==============================] - 132s 47ms/step - loss: 0.5679 - accuracy: 0.7181 - precision: 0.7068 - recall: 0.6661 - fbeta_score: 0.6922 - val_loss: 0.5780 - val_accuracy: 0.7182 - val_precision: 0.5795 - val_recall: 0.5330 - val_fbeta_score: 0.5523
#
# Epoch 00013: val_loss did not improve from 0.57321
# Epoch 14/60
# 2800/2800 [==============================] - 132s 47ms/step - loss: 0.5653 - accuracy: 0.7193 - precision: 0.7093 - recall: 0.6642 - fbeta_score: 0.6934 - val_loss: 0.5734 - val_accuracy: 0.7154 - val_precision: 0.5881 - val_recall: 0.4776 - val_fbeta_score: 0.5405
#
# Epoch 00014: val_loss did not improve from 0.57321
# Epoch 15/60
# 2800/2800 [==============================] - 131s 47ms/step - loss: 0.5622 - accuracy: 0.7223 - precision: 0.7108 - recall: 0.6741 - fbeta_score: 0.6971 - val_loss: 0.5858 - val_accuracy: 0.7129 - val_precision: 0.5737 - val_recall: 0.5664 - val_fbeta_score: 0.5587
#
# Epoch 00015: val_loss did not improve from 0.57321
# Epoch 16/60
# 2800/2800 [==============================] - 133s 47ms/step - loss: 0.5585 - accuracy: 0.7258 - precision: 0.7169 - recall: 0.6731 - fbeta_score: 0.7013 - val_loss: 0.5755 - val_accuracy: 0.7159 - val_precision: 0.5790 - val_recall: 0.5250 - val_fbeta_score: 0.5498
#
# Epoch 00016: val_loss did not improve from 0.57321
# Epoch 17/60
# 2800/2800 [==============================] - 131s 47ms/step - loss: 0.5562 - accuracy: 0.7275 - precision: 0.7161 - recall: 0.6811 - fbeta_score: 0.7024 - val_loss: 0.5770 - val_accuracy: 0.7121 - val_precision: 0.5698 - val_recall: 0.5660 - val_fbeta_score: 0.5547
#
# Epoch 00017: val_loss did not improve from 0.57321
# Epoch 18/60
# 2800/2800 [==============================] - 133s 47ms/step - loss: 0.5518 - accuracy: 0.7296 - precision: 0.7164 - recall: 0.6840 - fbeta_score: 0.7039 - val_loss: 0.5857 - val_accuracy: 0.7103 - val_precision: 0.5704 - val_recall: 0.5532 - val_fbeta_score: 0.5528
#
# Epoch 00018: val_loss did not improve from 0.57321
# Epoch 19/60
# 2800/2800 [==============================] - 132s 47ms/step - loss: 0.5492 - accuracy: 0.7315 - precision: 0.7188 - recall: 0.6870 - fbeta_score: 0.7065 - val_loss: 0.5868 - val_accuracy: 0.7105 - val_precision: 0.5834 - val_recall: 0.5653 - val_fbeta_score: 0.5630
#
# Epoch 00019: val_loss did not improve from 0.57321
# Epoch 20/60
# 2800/2800 [==============================] - 129s 46ms/step - loss: 0.5446 - accuracy: 0.7351 - precision: 0.7256 - recall: 0.6857 - fbeta_score: 0.7110 - val_loss: 0.5843 - val_accuracy: 0.7124 - val_precision: 0.5975 - val_recall: 0.5144 - val_fbeta_score: 0.5570
#
# Epoch 00020: val_loss did not improve from 0.57321
# Epoch 21/60
# 2800/2800 [==============================] - 131s 47ms/step - loss: 0.5414 - accuracy: 0.7368 - precision: 0.7263 - recall: 0.6897 - fbeta_score: 0.7127 - val_loss: 0.5867 - val_accuracy: 0.7163 - val_precision: 0.5901 - val_recall: 0.5430 - val_fbeta_score: 0.5631
#
# Epoch 00021: val_loss did not improve from 0.57321
# Epoch 22/60
# 2800/2800 [==============================] - 132s 47ms/step - loss: 0.5369 - accuracy: 0.7395 - precision: 0.7293 - recall: 0.6924 - fbeta_score: 0.7159 - val_loss: 0.5876 - val_accuracy: 0.7051 - val_precision: 0.5744 - val_recall: 0.5608 - val_fbeta_score: 0.5571
#
# Epoch 00022: val_loss did not improve from 0.57321
# Epoch 23/60
# 2800/2800 [==============================] - 130s 46ms/step - loss: 0.5330 - accuracy: 0.7432 - precision: 0.7364 - recall: 0.6931 - fbeta_score: 0.7214 - val_loss: 0.6014 - val_accuracy: 0.7064 - val_precision: 0.5919 - val_recall: 0.4844 - val_fbeta_score: 0.5451
#
# Epoch 00023: val_loss did not improve from 0.57321
# Epoch 24/60
# 2800/2800 [==============================] - 129s 46ms/step - loss: 0.5294 - accuracy: 0.7461 - precision: 0.7372 - recall: 0.7003 - fbeta_score: 0.7236 - val_loss: 0.5918 - val_accuracy: 0.7018 - val_precision: 0.5859 - val_recall: 0.4607 - val_fbeta_score: 0.5350
#
# Epoch 00024: val_loss did not improve from 0.57321
# Epoch 25/60
# 2800/2800 [==============================] - 129s 46ms/step - loss: 0.5256 - accuracy: 0.7477 - precision: 0.7400 - recall: 0.6983 - fbeta_score: 0.7256 - val_loss: 0.5838 - val_accuracy: 0.7124 - val_precision: 0.5968 - val_recall: 0.4896 - val_fbeta_score: 0.5491
#
# Epoch 00025: val_loss did not improve from 0.57321
# Epoch 26/60
# 2800/2800 [==============================] - 130s 47ms/step - loss: 0.5201 - accuracy: 0.7518 - precision: 0.7469 - recall: 0.7002 - fbeta_score: 0.7313 - val_loss: 0.5954 - val_accuracy: 0.7091 - val_precision: 0.5915 - val_recall: 0.4958 - val_fbeta_score: 0.5500
#
# Epoch 00026: val_loss did not improve from 0.57321
# Epoch 27/60
# 2800/2800 [==============================] - 128s 46ms/step - loss: 0.5136 - accuracy: 0.7557 - precision: 0.7513 - recall: 0.7050 - fbeta_score: 0.7356 - val_loss: 0.6156 - val_accuracy: 0.7042 - val_precision: 0.5788 - val_recall: 0.5421 - val_fbeta_score: 0.5594
#
# Epoch 00027: val_loss did not improve from 0.57321
# Epoch 28/60
# 2800/2800 [==============================] - 128s 46ms/step - loss: 0.5088 - accuracy: 0.7581 - precision: 0.7525 - recall: 0.7102 - fbeta_score: 0.7381 - val_loss: 0.6199 - val_accuracy: 0.7066 - val_precision: 0.5859 - val_recall: 0.5304 - val_fbeta_score: 0.5556
#
# Epoch 00028: val_loss did not improve from 0.57321
# Epoch 29/60
# 2800/2800 [==============================] - 128s 46ms/step - loss: 0.5056 - accuracy: 0.7611 - precision: 0.7575 - recall: 0.7083 - fbeta_score: 0.7417 - val_loss: 0.6070 - val_accuracy: 0.7037 - val_precision: 0.5967 - val_recall: 0.4690 - val_fbeta_score: 0.5465
#
# Epoch 00029: val_loss did not improve from 0.57321
# Epoch 30/60
# 2800/2800 [==============================] - 130s 47ms/step - loss: 0.4968 - accuracy: 0.7646 - precision: 0.7635 - recall: 0.7095 - fbeta_score: 0.7464 - val_loss: 0.6280 - val_accuracy: 0.7002 - val_precision: 0.5753 - val_recall: 0.5096 - val_fbeta_score: 0.5446
#
# Epoch 00030: val_loss did not improve from 0.57321
# Epoch 31/60
# 2800/2800 [==============================] - 131s 47ms/step - loss: 0.4929 - accuracy: 0.7679 - precision: 0.7655 - recall: 0.7150 - fbeta_score: 0.7492 - val_loss: 0.6201 - val_accuracy: 0.6958 - val_precision: 0.5812 - val_recall: 0.4820 - val_fbeta_score: 0.5440
#
# Epoch 00031: val_loss did not improve from 0.57321
# Epoch 32/60
# 2800/2800 [==============================] - 131s 47ms/step - loss: 0.4854 - accuracy: 0.7716 - precision: 0.7684 - recall: 0.7235 - fbeta_score: 0.7534 - val_loss: 0.6286 - val_accuracy: 0.6979 - val_precision: 0.5944 - val_recall: 0.4794 - val_fbeta_score: 0.5494
#
# Epoch 00032: val_loss did not improve from 0.57321
# Epoch 33/60
# 2800/2800 [==============================] - 128s 46ms/step - loss: 0.4801 - accuracy: 0.7754 - precision: 0.7770 - recall: 0.7213 - fbeta_score: 0.7596 - val_loss: 0.6469 - val_accuracy: 0.6967 - val_precision: 0.5977 - val_recall: 0.4712 - val_fbeta_score: 0.5444
#
# Epoch 00033: val_loss did not improve from 0.57321
# Epoch 34/60
# 2800/2800 [==============================] - 129s 46ms/step - loss: 0.4744 - accuracy: 0.7789 - precision: 0.7803 - recall: 0.7256 - fbeta_score: 0.7632 - val_loss: 0.6361 - val_accuracy: 0.6831 - val_precision: 0.5867 - val_recall: 0.4786 - val_fbeta_score: 0.5463
#
# Epoch 00034: val_loss did not improve from 0.57321
# Epoch 35/60
# 2800/2800 [==============================] - 132s 47ms/step - loss: 0.4664 - accuracy: 0.7838 - precision: 0.7817 - recall: 0.7394 - fbeta_score: 0.7676 - val_loss: 0.6593 - val_accuracy: 0.6954 - val_precision: 0.5709 - val_recall: 0.5455 - val_fbeta_score: 0.5545
#
# Epoch 00035: val_loss did not improve from 0.57321
# Epoch 36/60
# 2800/2800 [==============================] - 127s 45ms/step - loss: 0.4623 - accuracy: 0.7855 - precision: 0.7854 - recall: 0.7375 - fbeta_score: 0.7699 - val_loss: 0.6712 - val_accuracy: 0.6918 - val_precision: 0.5825 - val_recall: 0.4859 - val_fbeta_score: 0.5449
#
# Epoch 00036: val_loss did not improve from 0.57321
# Epoch 37/60
# 2800/2800 [==============================] - 127s 45ms/step - loss: 0.4555 - accuracy: 0.7896 - precision: 0.7945 - recall: 0.7371 - fbeta_score: 0.7770 - val_loss: 0.6799 - val_accuracy: 0.6909 - val_precision: 0.5680 - val_recall: 0.5435 - val_fbeta_score: 0.5511
#
# Epoch 00037: val_loss did not improve from 0.57321
# Epoch 38/60
# 2800/2800 [==============================] - 129s 46ms/step - loss: 0.4515 - accuracy: 0.7933 - precision: 0.7946 - recall: 0.7453 - fbeta_score: 0.7792 - val_loss: 0.6792 - val_accuracy: 0.6934 - val_precision: 0.5799 - val_recall: 0.4700 - val_fbeta_score: 0.5367
#
# Epoch 00038: val_loss did not improve from 0.57321
# Epoch 39/60
# 2800/2800 [==============================] - 129s 46ms/step - loss: 0.4411 - accuracy: 0.7981 - precision: 0.8018 - recall: 0.7472 - fbeta_score: 0.7851 - val_loss: 0.6669 - val_accuracy: 0.6896 - val_precision: 0.5809 - val_recall: 0.4711 - val_fbeta_score: 0.5400
#
# Epoch 00039: val_loss did not improve from 0.57321
# Epoch 40/60
# 2800/2800 [==============================] - 126s 45ms/step - loss: 0.4340 - accuracy: 0.8035 - precision: 0.8060 - recall: 0.7565 - fbeta_score: 0.7908 - val_loss: 0.7124 - val_accuracy: 0.6862 - val_precision: 0.5966 - val_recall: 0.4270 - val_fbeta_score: 0.5299
#
# Epoch 00040: val_loss did not improve from 0.57321
# Epoch 41/60
# 2800/2800 [==============================] - 129s 46ms/step - loss: 0.4350 - accuracy: 0.8023 - precision: 0.8087 - recall: 0.7496 - fbeta_score: 0.7913 - val_loss: 0.7065 - val_accuracy: 0.7002 - val_precision: 0.5788 - val_recall: 0.5287 - val_fbeta_score: 0.5561
#
# Epoch 00041: val_loss did not improve from 0.57321
# Epoch 42/60
# 2800/2800 [==============================] - 126s 45ms/step - loss: 0.4224 - accuracy: 0.8083 - precision: 0.8162 - recall: 0.7535 - fbeta_score: 0.7979 - val_loss: 0.7163 - val_accuracy: 0.6854 - val_precision: 0.5860 - val_recall: 0.4706 - val_fbeta_score: 0.5412
#
# Epoch 00042: val_loss did not improve from 0.57321
# Epoch 43/60
# 2800/2800 [==============================] - 127s 45ms/step - loss: 0.4218 - accuracy: 0.8091 - precision: 0.8157 - recall: 0.7572 - fbeta_score: 0.7983 - val_loss: 0.6872 - val_accuracy: 0.6783 - val_precision: 0.5650 - val_recall: 0.4808 - val_fbeta_score: 0.5314
#
# Epoch 00043: val_loss did not improve from 0.57321
# Epoch 44/60
# 2800/2800 [==============================] - 126s 45ms/step - loss: 0.4106 - accuracy: 0.8146 - precision: 0.8203 - recall: 0.7682 - fbeta_score: 0.8046 - val_loss: 0.7350 - val_accuracy: 0.6789 - val_precision: 0.5616 - val_recall: 0.4881 - val_fbeta_score: 0.5326
#
# Epoch 00044: val_loss did not improve from 0.57321
# Epoch 45/60
# 2800/2800 [==============================] - 127s 45ms/step - loss: 0.4041 - accuracy: 0.8192 - precision: 0.8249 - recall: 0.7734 - fbeta_score: 0.8095 - val_loss: 0.6965 - val_accuracy: 0.6902 - val_precision: 0.5833 - val_recall: 0.4870 - val_fbeta_score: 0.5463
#
# Epoch 00045: val_loss did not improve from 0.57321
# Epoch 46/60
# 2800/2800 [==============================] - 126s 45ms/step - loss: 0.3954 - accuracy: 0.8230 - precision: 0.8255 - recall: 0.7809 - fbeta_score: 0.8117 - val_loss: 0.7691 - val_accuracy: 0.6926 - val_precision: 0.5877 - val_recall: 0.4536 - val_fbeta_score: 0.5356
#
# Epoch 00046: val_loss did not improve from 0.57321
# Epoch 47/60
# 2800/2800 [==============================] - 129s 46ms/step - loss: 0.3910 - accuracy: 0.8250 - precision: 0.8308 - recall: 0.7803 - fbeta_score: 0.8155 - val_loss: 0.7695 - val_accuracy: 0.6755 - val_precision: 0.5574 - val_recall: 0.5526 - val_fbeta_score: 0.5475
#
# Epoch 00047: val_loss did not improve from 0.57321
# Epoch 48/60
# 2800/2800 [==============================] - 128s 46ms/step - loss: 0.3818 - accuracy: 0.8305 - precision: 0.8383 - recall: 0.7840 - fbeta_score: 0.8224 - val_loss: 0.7682 - val_accuracy: 0.6737 - val_precision: 0.5647 - val_recall: 0.4860 - val_fbeta_score: 0.5349
#
# Epoch 00048: val_loss did not improve from 0.57321
# Epoch 49/60
# 2800/2800 [==============================] - 129s 46ms/step - loss: 0.3773 - accuracy: 0.8320 - precision: 0.8376 - recall: 0.7893 - fbeta_score: 0.8231 - val_loss: 0.8899 - val_accuracy: 0.6837 - val_precision: 0.5817 - val_recall: 0.4787 - val_fbeta_score: 0.5440
#
# Epoch 00049: val_loss did not improve from 0.57321
# Epoch 50/60
# 2800/2800 [==============================] - 127s 45ms/step - loss: 0.3770 - accuracy: 0.8322 - precision: 0.8406 - recall: 0.7851 - fbeta_score: 0.8246 - val_loss: 0.7183 - val_accuracy: 0.6807 - val_precision: 0.5870 - val_recall: 0.4532 - val_fbeta_score: 0.5396
#
# Epoch 00050: val_loss did not improve from 0.57321
# Epoch 51/60
# 2800/2800 [==============================] - 129s 46ms/step - loss: 0.3648 - accuracy: 0.8391 - precision: 0.8474 - recall: 0.7945 - fbeta_score: 0.8320 - val_loss: 0.9469 - val_accuracy: 0.6789 - val_precision: 0.5507 - val_recall: 0.5449 - val_fbeta_score: 0.5414
#
# Epoch 00051: val_loss did not improve from 0.57321
# Epoch 52/60
# 2800/2800 [==============================] - 126s 45ms/step - loss: 0.3601 - accuracy: 0.8418 - precision: 0.8483 - recall: 0.7998 - fbeta_score: 0.8340 - val_loss: 0.8072 - val_accuracy: 0.6725 - val_precision: 0.5700 - val_recall: 0.4581 - val_fbeta_score: 0.5304
#
# Epoch 00052: val_loss did not improve from 0.57321
# Epoch 53/60
# 2800/2800 [==============================] - 129s 46ms/step - loss: 0.3915 - accuracy: 0.8249 - precision: 0.8320 - recall: 0.7782 - fbeta_score: 0.8158 - val_loss: 0.8616 - val_accuracy: 0.6629 - val_precision: 0.5392 - val_recall: 0.5419 - val_fbeta_score: 0.5319
#
# Epoch 00053: val_loss did not improve from 0.57321
# Epoch 54/60
# 2800/2800 [==============================] - 126s 45ms/step - loss: 0.3463 - accuracy: 0.8488 - precision: 0.8568 - recall: 0.8076 - fbeta_score: 0.8424 - val_loss: 0.8445 - val_accuracy: 0.6671 - val_precision: 0.5580 - val_recall: 0.4668 - val_fbeta_score: 0.5263
#
# Epoch 00054: val_loss did not improve from 0.57321
# Epoch 55/60
# 2800/2800 [==============================] - 128s 46ms/step - loss: 0.3396 - accuracy: 0.8522 - precision: 0.8599 - recall: 0.8125 - fbeta_score: 0.8460 - val_loss: 0.7995 - val_accuracy: 0.6687 - val_precision: 0.5482 - val_recall: 0.5278 - val_fbeta_score: 0.5348
#
# Epoch 00055: val_loss did not improve from 0.57321
# Epoch 56/60
# 2800/2800 [==============================] - 129s 46ms/step - loss: 0.3587 - accuracy: 0.8429 - precision: 0.8489 - recall: 0.8032 - fbeta_score: 0.8353 - val_loss: 0.9119 - val_accuracy: 0.6664 - val_precision: 0.5331 - val_recall: 0.6050 - val_fbeta_score: 0.5399
#
# Epoch 00056: val_loss did not improve from 0.57321
# Epoch 57/60
# 2800/2800 [==============================] - 129s 46ms/step - loss: 0.3318 - accuracy: 0.8576 - precision: 0.8626 - recall: 0.8230 - fbeta_score: 0.8505 - val_loss: 0.9155 - val_accuracy: 0.6704 - val_precision: 0.5494 - val_recall: 0.5366 - val_fbeta_score: 0.5383
#
# Epoch 00057: val_loss did not improve from 0.57321
# Epoch 58/60
# 2800/2800 [==============================] - 128s 46ms/step - loss: 0.3256 - accuracy: 0.8595 - precision: 0.8645 - recall: 0.8255 - fbeta_score: 0.8527 - val_loss: 0.9028 - val_accuracy: 0.6671 - val_precision: 0.5430 - val_recall: 0.5590 - val_fbeta_score: 0.5381
#
# Epoch 00058: val_loss did not improve from 0.57321
# Epoch 59/60
# 2800/2800 [==============================] - 127s 45ms/step - loss: 0.3333 - accuracy: 0.8560 - precision: 0.8611 - recall: 0.8207 - fbeta_score: 0.8490 - val_loss: 0.8714 - val_accuracy: 0.6606 - val_precision: 0.5463 - val_recall: 0.5050 - val_fbeta_score: 0.5282
#
# Epoch 00059: val_loss did not improve from 0.57321
# Epoch 60/60
# 2800/2800 [==============================] - 126s 45ms/step - loss: 0.3070 - accuracy: 0.8678 - precision: 0.8744 - recall: 0.8341 - fbeta_score: 0.8625 - val_loss: 0.9504 - val_accuracy: 0.6721 - val_precision: 0.5467 - val_recall: 0.5107 - val_fbeta_score: 0.5305
#
# Epoch 00060: val_loss did not improve from 0.57321
# training time: 130.38 minutes

# %%
model.load_weights('saved_models/pretrainedVGG.best.from_scratch.hdf5')
prediction = model.predict(test_tensors)
# Out:
# 2022-11-29 20:41:38.659083: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 556400640 exceeds 10% of free system memory.
# 2022-11-29 20:41:38.967703: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 556400640 exceeds 10% of free system memory.

# %%
threshold = 0.5
beta = 0.5

pre = K.eval(precision_threshold(threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))
rec = K.eval(recall_threshold(threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))
fsc = K.eval(fbeta_score_threshold(beta = beta, threshold = threshold)(K.variable(value=test_labels),
                                   K.variable(value=prediction)))

print ("Precision: %f %%\nRecall: %f \nf1-score: %f "% (pre, rec, fsc))
# Out:
# Precision: 0.704487 %
# Recall: 0.595126
# f1-score: 0.679514

# %%
K.eval(binary_accuracy(K.variable(value=test_labels),
                       K.variable(value=prediction)))
# Out:
# 0.67968196

# %%
import matplotlib.pyplot as plt  

plt.figure(1, figsize = (15,8))  
    
plt.subplot(222)  
plt.plot(history.history['loss'])  
plt.plot(history.history['val_loss'])  
plt.title('vgg16 model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 

plt.show()

# %%
plt.figure(1, figsize = (15,8))  
    
plt.subplot(222)  
plt.plot(history.history['accuracy'])  
plt.plot(history.history['val_accuracy'])  
plt.title('vgg16 model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 

plt.show()

# %%
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])

plt.title('efficient-net model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])

plt.title('efficient-net model precision')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.save("vgg16_adam.h5")
model.save_weights('vgg16_weights_adam.h5')

# %%
pred = model.predict(test_tensors)
# Out:
# 2022-11-29 20:41:45.979022: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 556400640 exceeds 10% of free system memory.
# 2022-11-29 20:41:46.920739: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 556400640 exceeds 10% of free system memory.

# %%
pred = np.argmax(pred,axis=1)

# %%
from sklearn.metrics import accuracy_score

# %%
x = accuracy_score(pred,test_labels)

# %%
x
# Out:
# 0.5106007067137809
