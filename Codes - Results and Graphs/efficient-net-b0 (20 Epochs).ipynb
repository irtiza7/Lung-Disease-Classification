# %%
import numpy as np
import pandas as pd
from glob import glob
from tqdm import tqdm
from sklearn.utils import shuffle

df = pd.read_csv('../input/data/Data_Entry_2017.csv')

diseases = ['Cardiomegaly','Emphysema','Effusion','Hernia','Nodule','Pneumothorax','Atelectasis','Pleural_Thickening','Mass','Edema','Consolidation','Infiltration','Fibrosis','Pneumonia']
#Number diseases
for disease in diseases :
    df[disease] = df['Finding Labels'].apply(lambda x: 1 if disease in x else 0)

# %%
import os
labels = df[diseases].to_numpy()
all_image_paths = {os.path.basename(x): x for x in glob(os.path.join('..', 'input','data','images*','images','*.png'))}

print('Images found:', len(all_image_paths))

df['Path'] = df['Image Index'].map(all_image_paths.get)
files_list = df['Path'].tolist()

labelB = (df[diseases].sum(axis=1)>0).tolist()
labelB = np.array(labelB, dtype=int)
# Out:
# Images found: 112120

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path, shape):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=shape)
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)/255
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths, shape):
    list_of_tensors = [path_to_tensor(img_path, shape) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

train_labels = labelB[:89600][:, np.newaxis]
valid_labels = labelB[89600:100800][:, np.newaxis]
test_labels = labelB[100800:][:, np.newaxis]


img_shape = (64, 64)
train_tensors = paths_to_tensor(files_list[:89600], shape = img_shape)
valid_tensors = paths_to_tensor(files_list[89600:100800], shape = img_shape)
test_tensors = paths_to_tensor(files_list[100800:], shape = img_shape)
# Out:
# 100%|██████████| 89600/89600 [35:49<00:00, 41.68it/s]
# 100%|██████████| 11200/11200 [04:48<00:00, 38.76it/s]
# 100%|██████████| 11320/11320 [04:48<00:00, 39.29it/s]

# %%
import time

from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dropout, Flatten, Dense
from keras.models import Sequential, Model
from keras.layers import BatchNormalization
from keras import regularizers, applications, optimizers, initializers
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0

base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=train_tensors.shape[1:])

add_model = Sequential()
add_model.add(GlobalAveragePooling2D(input_shape=base_model.output_shape[1:]))
add_model.add(Dropout(0.2))
add_model.add(Dense(256, activation='relu'))
add_model.add(Dropout(0.2))
add_model.add(Dense(50, activation='relu'))
add_model.add(Dropout(0.2))
add_model.add(Dense(1, activation='sigmoid'))

model = Model(inputs=base_model.input, outputs=add_model(base_model.output))

# model.summary()
# Out:
# 2022-11-30 19:02:21.719728: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 19:02:21.920460: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 19:02:21.921496: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 19:02:21.922976: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-30 19:02:21.923382: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 19:02:21.924312: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 19:02:21.925055: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 19:02:24.162478: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 19:02:24.163508: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 19:02:24.164275: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-30 19:02:24.165840: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 1s 0us/step
# 16719872/16705208 [==============================] - 1s 0us/step

# %%
from keras import backend as K

def binary_accuracy(y_true, y_pred):
    return K.mean(K.equal(y_true, K.round(y_pred)))

def precision_threshold(threshold = 0.5):
    def precision(y_true, y_pred):
        threshold_value = threshold
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold_value), K.floatx())
        true_positives = K.round(K.sum(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(y_pred)
        precision_ratio = true_positives / (predicted_positives + K.epsilon())
        return precision_ratio
    return precision

def recall_threshold(threshold = 0.5):
    def recall(y_true, y_pred):
        threshold_value = threshold
        y_pred = K.cast(K.greater(K.clip(y_pred, 0, 1), threshold_value), K.floatx())
        true_positives = K.round(K.sum(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.clip(y_true, 0, 1))
        recall_ratio = true_positives / (possible_positives + K.epsilon())
        return recall_ratio
    return recall

def fbeta_score_threshold(beta = 1, threshold = 0.5):
    def fbeta_score(y_true, y_pred):
        threshold_value = threshold
        beta_value = beta
        p = precision_threshold(threshold_value)(y_true, y_pred)
        r = recall_threshold(threshold_value)(y_true, y_pred)
        bb = beta_value ** 2
        fbeta_score = (1 + bb) * (p * r) / (bb * p + r + K.epsilon())
        return fbeta_score
    return fbeta_score

# %%
import keras.backend as K
import tensorflow as tf

model.compile(
    optimizer=tf.keras.optimizers.SGD(lr=1e-4, decay=1e-6, momentum=0.9, nesterov=True), 
    loss='binary_crossentropy', 
    metrics=[
        'accuracy',
        precision_threshold(threshold = 0.5), 
        recall_threshold(threshold = 0.5), 
        fbeta_score_threshold(beta=0.5, threshold = 0.5)
    ]
)
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping
import numpy as np

epochs = 20
batch_size = 32

earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=4, verbose=1, mode='auto')
log = CSVLogger('saved_models/log_pretrained_CNN.csv')
checkpointer = ModelCheckpoint(filepath='saved_models/pretrainedVGG.best.from_scratch.hdf5', verbose=1, save_best_only=True)

start = time.time()
train_datagen = ImageDataGenerator(
                        featurewise_center=False,  # set input mean to 0 over the dataset
                        samplewise_center=False,  # set each sample mean to 0
                        featurewise_std_normalization=False,  # divide inputs by std of the dataset
                        samplewise_std_normalization=False,  # divide each input by its std
                        zca_whitening=False,  # apply ZCA whitening
                        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
                        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
                        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
                        horizontal_flip=True,  # randomly flip images
                        vertical_flip=False 
)



# Training with data augmentation. If shift_fraction=0., also no augmentation.
history = model.fit_generator(
    train_datagen.flow(train_tensors,train_labels, batch_size = batch_size),
    steps_per_epoch = len(train_tensors) // batch_size,
    validation_data = (valid_tensors, valid_labels),
    validation_steps = len(valid_tensors) // batch_size,
    epochs = epochs,
    callbacks=[checkpointer, log], verbose=1
)
print("training time: %.2f minutes"%((time.time()-start)/60))
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2022-11-30 19:02:26.915128: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/20
# 2022-11-30 19:02:35.594011: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 2800/2800 [==============================] - ETA: 0s - loss: 0.7085 - accuracy: 0.5400 - precision: 0.5018 - recall: 0.4610 - fbeta_score: 0.4845
# 2022-11-30 19:05:57.886932: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 550502400 exceeds 10% of free system memory.
# 2022-11-30 19:05:58.196227: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 550502400 exceeds 10% of free system memory.
# 2800/2800 [==============================] - 217s 72ms/step - loss: 0.7085 - accuracy: 0.5400 - precision: 0.5018 - recall: 0.4610 - fbeta_score: 0.4845 - val_loss: 0.8081 - val_accuracy: 0.5501 - val_precision: 0.4639 - val_recall: 0.2525 - val_fbeta_score: 0.3777
#
# Epoch 00001: val_loss improved from inf to 0.80812, saving model to saved_models/pretrainedVGG.best.from_scratch.hdf5
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/20
# 2800/2800 [==============================] - 200s 71ms/step - loss: 0.6842 - accuracy: 0.5691 - precision: 0.5400 - recall: 0.4463 - fbeta_score: 0.5114 - val_loss: 4.3224 - val_accuracy: 0.5175 - val_precision: 0.4424 - val_recall: 0.3205 - val_fbeta_score: 0.3885
#
# Epoch 00002: val_loss did not improve from 0.80812
# Epoch 3/20
# 2800/2800 [==============================] - 202s 72ms/step - loss: 0.6735 - accuracy: 0.5884 - precision: 0.5673 - recall: 0.4597 - fbeta_score: 0.5349 - val_loss: 0.6927 - val_accuracy: 0.5394 - val_precision: 0.4390 - val_recall: 0.1215 - val_fbeta_score: 0.2459
#
# Epoch 00003: val_loss improved from 0.80812 to 0.69268, saving model to saved_models/pretrainedVGG.best.from_scratch.hdf5
# Epoch 4/20
# 2800/2800 [==============================] - 200s 71ms/step - loss: 0.6664 - accuracy: 0.5998 - precision: 0.5837 - recall: 0.4670 - fbeta_score: 0.5490 - val_loss: 535.8598 - val_accuracy: 0.5448 - val_precision: 0.4570 - val_recall: 0.2245 - val_fbeta_score: 0.3535
#
# Epoch 00004: val_loss did not improve from 0.69268
# Epoch 5/20
# 2800/2800 [==============================] - 196s 70ms/step - loss: 0.6605 - accuracy: 0.6099 - precision: 0.5957 - recall: 0.4826 - fbeta_score: 0.5628 - val_loss: 153.9519 - val_accuracy: 0.5149 - val_precision: 0.4403 - val_recall: 0.2610 - val_fbeta_score: 0.3525
#
# Epoch 00005: val_loss did not improve from 0.69268
# Epoch 6/20
# 2800/2800 [==============================] - 194s 69ms/step - loss: 0.6568 - accuracy: 0.6163 - precision: 0.6016 - recall: 0.5035 - fbeta_score: 0.5727 - val_loss: 0.6869 - val_accuracy: 0.5333 - val_precision: 0.4479 - val_recall: 0.2730 - val_fbeta_score: 0.3696
#
# Epoch 00006: val_loss improved from 0.69268 to 0.68687, saving model to saved_models/pretrainedVGG.best.from_scratch.hdf5
# Epoch 7/20
# 2800/2800 [==============================] - 197s 70ms/step - loss: 0.6531 - accuracy: 0.6204 - precision: 0.6058 - recall: 0.5127 - fbeta_score: 0.5783 - val_loss: 0.6799 - val_accuracy: 0.5829 - val_precision: 0.4810 - val_recall: 0.4314 - val_fbeta_score: 0.4575
#
# Epoch 00007: val_loss improved from 0.68687 to 0.67994, saving model to saved_models/pretrainedVGG.best.from_scratch.hdf5
# Epoch 8/20
# 2800/2800 [==============================] - 196s 70ms/step - loss: 0.6502 - accuracy: 0.6274 - precision: 0.6120 - recall: 0.5311 - fbeta_score: 0.5879 - val_loss: 0.7030 - val_accuracy: 0.5507 - val_precision: 0.4572 - val_recall: 0.1249 - val_fbeta_score: 0.2732
#
# Epoch 00008: val_loss did not improve from 0.67994
# Epoch 9/20
# 2800/2800 [==============================] - 197s 71ms/step - loss: 0.6478 - accuracy: 0.6309 - precision: 0.6167 - recall: 0.5313 - fbeta_score: 0.5919 - val_loss: 5.4785 - val_accuracy: 0.4991 - val_precision: 0.4460 - val_recall: 0.5110 - val_fbeta_score: 0.4419
#
# Epoch 00009: val_loss did not improve from 0.67994
# Epoch 10/20
# 2800/2800 [==============================] - 206s 74ms/step - loss: 0.6459 - accuracy: 0.6337 - precision: 0.6185 - recall: 0.5410 - fbeta_score: 0.5956 - val_loss: 0.6943 - val_accuracy: 0.5179 - val_precision: 0.4426 - val_recall: 0.3263 - val_fbeta_score: 0.3915
#
# Epoch 00010: val_loss did not improve from 0.67994
# Epoch 11/20
# 2800/2800 [==============================] - 207s 74ms/step - loss: 0.6457 - accuracy: 0.6347 - precision: 0.6215 - recall: 0.5374 - fbeta_score: 0.5971 - val_loss: 0.6881 - val_accuracy: 0.5419 - val_precision: 0.4707 - val_recall: 0.4472 - val_fbeta_score: 0.4464
#
# Epoch 00011: val_loss did not improve from 0.67994
# Epoch 12/20
# 2800/2800 [==============================] - 207s 74ms/step - loss: 0.6420 - accuracy: 0.6392 - precision: 0.6253 - recall: 0.5498 - fbeta_score: 0.6029 - val_loss: 0.6883 - val_accuracy: 0.5709 - val_precision: 0.4430 - val_recall: 0.1146 - val_fbeta_score: 0.2543
#
# Epoch 00012: val_loss did not improve from 0.67994
# Epoch 13/20
# 2800/2800 [==============================] - 207s 74ms/step - loss: 0.6418 - accuracy: 0.6417 - precision: 0.6268 - recall: 0.5566 - fbeta_score: 0.6060 - val_loss: 0.6779 - val_accuracy: 0.5809 - val_precision: 0.5132 - val_recall: 0.2263 - val_fbeta_score: 0.3851
#
# Epoch 00013: val_loss improved from 0.67994 to 0.67787, saving model to saved_models/pretrainedVGG.best.from_scratch.hdf5
# Epoch 14/20
# 2800/2800 [==============================] - 208s 74ms/step - loss: 0.6384 - accuracy: 0.6437 - precision: 0.6284 - recall: 0.5579 - fbeta_score: 0.6075 - val_loss: 0.9005 - val_accuracy: 0.5180 - val_precision: 0.4359 - val_recall: 0.3159 - val_fbeta_score: 0.3806
#
# Epoch 00014: val_loss did not improve from 0.67787
# Epoch 15/20
# 2800/2800 [==============================] - 209s 74ms/step - loss: 0.6361 - accuracy: 0.6462 - precision: 0.6317 - recall: 0.5631 - fbeta_score: 0.6114 - val_loss: 0.6731 - val_accuracy: 0.5804 - val_precision: 0.4817 - val_recall: 0.1829 - val_fbeta_score: 0.3394
#
# Epoch 00015: val_loss improved from 0.67787 to 0.67312, saving model to saved_models/pretrainedVGG.best.from_scratch.hdf5
# Epoch 16/20
# 2800/2800 [==============================] - 209s 75ms/step - loss: 0.6367 - accuracy: 0.6459 - precision: 0.6324 - recall: 0.5601 - fbeta_score: 0.6111 - val_loss: 0.6845 - val_accuracy: 0.5554 - val_precision: 0.3009 - val_recall: 0.0360 - val_fbeta_score: 0.1105
#
# Epoch 00016: val_loss did not improve from 0.67312
# Epoch 17/20
# 2800/2800 [==============================] - 207s 74ms/step - loss: 0.6363 - accuracy: 0.6491 - precision: 0.6342 - recall: 0.5681 - fbeta_score: 0.6145 - val_loss: 0.6961 - val_accuracy: 0.5218 - val_precision: 0.4612 - val_recall: 0.7737 - val_fbeta_score: 0.4921
#
# Epoch 00017: val_loss did not improve from 0.67312
# Epoch 18/20
# 2800/2800 [==============================] - 207s 74ms/step - loss: 0.6332 - accuracy: 0.6511 - precision: 0.6374 - recall: 0.5718 - fbeta_score: 0.6177 - val_loss: 0.6714 - val_accuracy: 0.5888 - val_precision: 0.4911 - val_recall: 0.4030 - val_fbeta_score: 0.4552
#
# Epoch 00018: val_loss improved from 0.67312 to 0.67140, saving model to saved_models/pretrainedVGG.best.from_scratch.hdf5
# Epoch 19/20
# 2800/2800 [==============================] - 207s 74ms/step - loss: 0.6314 - accuracy: 0.6540 - precision: 0.6400 - recall: 0.5747 - fbeta_score: 0.6206 - val_loss: 0.6729 - val_accuracy: 0.5750 - val_precision: 0.4647 - val_recall: 0.1006 - val_fbeta_score: 0.2432
#
# Epoch 00019: val_loss did not improve from 0.67140
# Epoch 20/20
# 2800/2800 [==============================] - 206s 74ms/step - loss: 0.6290 - accuracy: 0.6565 - precision: 0.6429 - recall: 0.5788 - fbeta_score: 0.6237 - val_loss: 0.7183 - val_accuracy: 0.4610 - val_precision: 0.4158 - val_recall: 0.3854 - val_fbeta_score: 0.3785
#
# Epoch 00020: val_loss did not improve from 0.67140
# training time: 69.88 minutes

# %%
prediction = model.predict(test_tensors)
# Out:
# 2022-11-30 20:12:19.848628: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 556400640 exceeds 10% of free system memory.
# 2022-11-30 20:12:20.159709: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 556400640 exceeds 10% of free system memory.

# %%
import matplotlib.pyplot as plt  

plt.figure(1, figsize = (15,8))  
    
plt.subplot(222)  
plt.plot(history.history['loss'])  
plt.plot(history.history['val_loss'])  
plt.title('efficient-net model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 

plt.show()

# %%
import matplotlib.pyplot as plt  

plt.figure(1, figsize = (15,8))  
    
plt.subplot(222)  
plt.plot(history.history['accuracy'])  
plt.plot(history.history['val_accuracy'])  
plt.title('efficient-net model accuracy')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid']) 

plt.show()

# %%
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])

plt.title('efficient-net model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])

plt.title('efficient-net model precision')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
threshold = 0.5
beta = 0.5

pre = K.eval(precision_threshold(threshold = threshold)(K.variable(value=test_labels),K.variable(value=prediction)))
rec = K.eval(recall_threshold(threshold = threshold)(K.variable(value=test_labels),K.variable(value=prediction)))
fsc = K.eval(fbeta_score_threshold(beta = beta, threshold = threshold)(K.variable(value=test_labels),K.variable(value=prediction)))

print ("Precision: %f %%\nRecall: %f \nF1-score: %f"% (pre, rec, fsc))
# Out:
# Precision: 0.445967 %
# Recall: 0.252527
# F1-score: 0.386720

# %%
K.eval(binary_accuracy(K.variable(value=test_labels), K.variable(value=prediction)))
# Out:
# 0.4806537
