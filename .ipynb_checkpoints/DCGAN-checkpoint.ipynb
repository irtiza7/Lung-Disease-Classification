# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))


from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten
from keras.layers import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
import os
import time
from tqdm import tqdm
from tensorflow.keras.preprocessing.image import load_img, img_to_array
# Out:
# <style>.container { width:100% !important; }</style>

# %%
CLASS_NAME = "Cardiomegaly"
img_input_size = 300
SIZE_OF_LATENT_VECTOR = 300
EPOCHS = 600000
BATCH_SIZE = 32

img_rows = img_input_size
img_cols = img_input_size
channels = 1
img_shape = (img_rows, img_cols, channels)

# %%
def save_imgs(epoch):
    r, c = 6, 6
    noise = np.random.normal(0, 1, (r * c, SIZE_OF_LATENT_VECTOR))
    gen_imgs = generator.predict(noise)

    # Rescale images 0 - 1
    gen_imgs = 0.5 * gen_imgs + 0.5

    fig, axs = plt.subplots(r, c, figsize=(10, 10))
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i,j].imshow(gen_imgs[cnt, :,:,0], cmap='gray')
            axs[i,j].axis('off')
            cnt += 1
    
    fig.savefig(f"GAN2_images\\{CLASS_NAME}\\{epoch}.png", dpi=400)
    plt.close()

# %%
def build_generator():
    noise_shape = (SIZE_OF_LATENT_VECTOR,) #1D array of SIZE_OF_NOISE (latent vector / noise)

    model = Sequential()
    model.add(Dense(256, input_shape=noise_shape))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    
    model.add(Dense(1024))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    
    model.add(Dense(1024))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    
    model.add(Dense(np.prod(img_shape), activation='tanh'))
    model.add(Reshape(img_shape))

#     model.summary()
    
    noise = Input(shape=noise_shape)
    img = model(noise)    #Generated image
    return Model(noise, img)

# %%
def build_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=img_shape))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(256))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(128))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(1, activation='sigmoid'))
    
#     model.summary()

    img = Input(shape=img_shape)
    validity = model(img)
    return Model(img, validity)

# %%
discriminator_accuracies = []
discriminator_losses = []
generator_losses = []

def train(epochs, batch_size = 128, save_interval = 500):
    dataset_path = f"D:\\Datasets\\Mutually_Exclusive_Images\\{CLASS_NAME} 2"
    filenames = os.listdir(dataset_path)
    
    X_train = []
    for filename in filenames:
        img = load_img(os.path.join(dataset_path, filename), color_mode = 'grayscale', target_size = (img_input_size, img_input_size))
        img_arr = img_to_array(img)
        X_train.append(img_arr)

    X_train = np.array(X_train)
    X_train = (X_train.astype(np.float32) - 127.5) / 127.5
    X_train = np.expand_dims(X_train, axis = 3)
    
    # So we can feed half real and half fake images to the discriminator model for training
    half_batch = int(batch_size / 2)
    
    for epoch in tqdm(range(1, epochs + 1), ncols = 100):
        idx = np.random.randint(0, X_train.shape[0], half_batch)
        imgs = X_train[idx]
 
        noise = np.random.normal(0, 1, (half_batch, SIZE_OF_LATENT_VECTOR))
        gen_imgs = generator.predict(noise)
 
        d_loss_real = discriminator.train_on_batch(imgs, np.ones((half_batch, 1)))
        d_loss_fake = discriminator.train_on_batch(gen_imgs, np.zeros((half_batch, 1)))
        
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) 
        
        noise = np.random.normal(0, 1, (batch_size, SIZE_OF_LATENT_VECTOR)) 
        valid_y = np.array([1] * batch_size)
        
        g_loss = combined.train_on_batch(noise, valid_y)
        
        if epoch == 1 or epoch % 500 == 0:
#             print(f"Epoch: {epoch}/{EPOCHS} - Disc_Loss: {d_loss[0]:.2f} Disc_Acc: {100 * d_loss[1]}, Gen_Loss: {g_loss:.2f}")
            discriminator_losses.append(d_loss[0])
            discriminator_accuracies.append(d_loss[1] * 100)
            generator_losses.append(g_loss)
            
        if epoch == 1 or epoch % save_interval == 0:
            save_imgs(epoch)
            if epoch == 1: continue
            generator.save(f"./GAN2_images/{CLASS_NAME}/generator_model_{epoch}_epochs.h5")

# %%
optimizer = Adam(0.0002, 0.5)

discriminator = build_discriminator()
discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

generator = build_generator()
# generator.load_weights(f"./GAN2_images/{CLASS_NAME}/generator_model_{300000}_epochs.h5")
generator.compile(loss = 'binary_crossentropy', optimizer = optimizer)

z = Input(shape=(SIZE_OF_LATENT_VECTOR,))
img = generator(z)
  
discriminator.trainable = False
valid = discriminator(img)

combined = Model(z, valid)
combined.compile(loss = 'binary_crossentropy', optimizer = optimizer)

# %%
train(epochs = EPOCHS, batch_size = BATCH_SIZE, save_interval = 20000)
# Out:
#  94%|██████████████████████████████████████████████▊   | 561451/600000 [37:57:40<2:36:23,  4.11it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-5d5a742d37ee> in <module>
# ----> 1 train(epochs = EPOCHS, batch_size = BATCH_SIZE, save_interval = 20000)
#
# <ipython-input-9-d7ffd5e2b912> in train(epochs, batch_size, save_interval)
#      35         valid_y = np.array([1] * batch_size)
#      36
# ---> 37         g_loss = combined.train_on_batch(noise, valid_y)
#      38
#      39         if epoch == 1 or epoch % 500 == 0:
#
# ~\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1858     if reset_metrics:
#    1859       self.reset_metrics()
# -> 1860     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1861     if return_dict:
# ...

# %%
generator.save(f"./GAN2_images/{CLASS_NAME}/generator_model_{EPOCHS}_epochs.h5")

# %%
x_values = list(range(1, len(discriminator_losses) + 1))
fig = plt.figure(figsize=(14, 8))

plt.plot(x_values, discriminator_losses, label='Discriminator')
plt.plot(x_values, generator_losses, label='Generator')

# Adding a title and labels for the x- and y- axes
plt.title('Loss for Discriminator and Generator')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# Adding a legend for the two lists
plt.legend()

# Displaying the plot
plt.show()

# %%
x_values = list(range(1, len(discriminator_accuracies)+1))
fig = plt.figure(figsize=(12, 8))

plt.plot(x_values, discriminator_accuracies, label='Discriminator')

plt.title('Accuracy for Discriminator')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

# Adding a legend for the two lists
plt.legend()

# Displaying the plot
plt.show()

# %%
def generate_image():
    noise = np.random.normal(0, 1, (1, SIZE_OF_LATENT_VECTOR))
    gen_img = generator.predict(noise)[0]
    gen_img = 0.5 * gen_img + 0.5
    return gen_img

for i in tqdm(range(300), ncols = 100):
    gen_img = generate_image()
    
    filename = f"image_{i}.png"
    filepath = os.path.join(f"./GAN2_images/{CLASS_NAME}/", filename)
    plt.imshow(gen_img, cmap='gray')
    plt.axis('off')
    plt.savefig(filepath, dpi=1200, bbox_inches='tight')
    plt.close()
# Out:
# 100%|█████████████████████████████████████████████████████████████| 300/300 [12:47<00:00,  2.56s/it]

# %%
# dataset.plot_class_samples(total_samples_per_class, exclusive_samples_per_class)
